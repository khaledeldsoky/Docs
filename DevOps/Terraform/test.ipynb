# %%
Host bootstrap
    HostName 
    User vpcuser
    IdentityFile ~/.ssh/master
    StrictHostKeyChecking no
Host control-plane-1
    HostName 
    User vpcuser
    IdentityFile ~/.ssh/master
    StrictHostKeyChecking no
Host control-plane-2
    HostName 
    User vpcuser
    IdentityFile ~/.ssh/master
    StrictHostKeyChecking no
Host lb-1
    HostName 
    User vpcuser
    IdentityFile ~/.ssh/master
    StrictHostKeyChecking no
Host lb-2
    HostName 
    User vpcuser
    IdentityFile ~/.ssh/master
    StrictHostKeyChecking no
Host worker
    HostName 
    User vpcuser
    IdentityFile ~/.ssh/master
    StrictHostKeyChecking no
