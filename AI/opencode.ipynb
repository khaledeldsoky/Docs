# %%
sudo snap install opencode --classic

# %% [markdown]
# Opencode cli

# %%
opencode

# %% [markdown]
# List opencode sessions IDs

# %%
opencode session list

# %% [markdown]
# Open specific sesion

# %%
opencode -s <SESSION_ID>
